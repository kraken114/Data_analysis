# %%
import pandas as pd
import numpy as np
from pandas import read_csv

# %%
df=read_csv('D:\Политех\Класиффикация\Сегментация_клиентов\Train_cleared_dropna.csv')

# %%
df_T=read_csv('D:\Политех\Класиффикация\Сегментация_клиентов\TEST_cleared_dropna.csv')

# %%
df=df.filter(regex='^(?!.*Unnamed).*$')

# %%
df_T=df_T.filter(regex='^(?!.*Unnamed).*$')

# %% [markdown]
# ================================================================

# %% [markdown]
# **Обучающий_набор**

# %%
array = df.values
array
# Out:
# array([[ 1.,  0., 22., ...,  4.,  4.,  4.],
#        [ 0.,  1., 67., ...,  1.,  6.,  2.],
#        [ 1.,  1., 67., ...,  2.,  6.,  2.],
#        ...,
#        [ 0.,  0., 33., ...,  1.,  6.,  4.],
#        [ 0.,  0., 27., ...,  4.,  6.,  2.],
#        [ 1.,  1., 37., ...,  3.,  4.,  2.]])

# %%
X = array[:,0:9]
Y = array[:,9]

# %%
X
# Out:
# array([[ 1.,  0., 22., ...,  3.,  4.,  4.],
#        [ 0.,  1., 67., ...,  3.,  1.,  6.],
#        [ 1.,  1., 67., ...,  1.,  2.,  6.],
#        ...,
#        [ 0.,  0., 33., ...,  3.,  1.,  6.],
#        [ 0.,  0., 27., ...,  3.,  4.,  6.],
#        [ 1.,  1., 37., ...,  2.,  3.,  4.]])

# %%
Y
# Out:
# array([4., 2., 2., ..., 4., 2., 2.])

# %% [markdown]
# ==============================================================

# %% [markdown]
# **Тестовый_набор**

# %%
array_T = df.values
array_T
# Out:
# array([[ 1.,  0., 22., ...,  4.,  4.,  4.],
#        [ 0.,  1., 67., ...,  1.,  6.,  2.],
#        [ 1.,  1., 67., ...,  2.,  6.,  2.],
#        ...,
#        [ 0.,  0., 33., ...,  1.,  6.,  4.],
#        [ 0.,  0., 27., ...,  4.,  6.,  2.],
#        [ 1.,  1., 37., ...,  3.,  4.,  2.]])

# %%
XX = array_T[:,0:9]
YY = array_T[:,9]

# %%
XX
# Out:
# array([[ 1.,  0., 22., ...,  3.,  4.,  4.],
#        [ 0.,  1., 67., ...,  3.,  1.,  6.],
#        [ 1.,  1., 67., ...,  1.,  2.,  6.],
#        ...,
#        [ 0.,  0., 33., ...,  3.,  1.,  6.],
#        [ 0.,  0., 27., ...,  3.,  4.,  6.],
#        [ 1.,  1., 37., ...,  2.,  3.,  4.]])

# %%
YY
# Out:
# array([4., 2., 2., ..., 4., 2., 2.])

# %% [markdown]
# =====================================================

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
# отбор признаков:
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
# ансамблевые функции:
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
import numpy as np
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import GridSearchCV
from scipy.stats import uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
# сохраняет параметры после перезагрузки:
import pickle
import joblib

# %%
+++++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
#   File "C:\Users\D9F8~1\AppData\Local\Temp/ipykernel_17880/441078461.py", line 1
#     +++++++++++++++++++++++++++++++++++++++++++++++++++++
#                                                          ^
# SyntaxError: invalid syntax

# %%
kfold = KFold(n_splits= 10, random_state = 7, shuffle=True)

# %%
cart = DecisionTreeClassifier() # модель решающего дерева

# %% [markdown]
# **деревья_решенией (Bagged Decision Trees)**

# %%
model = BaggingClassifier(base_estimator=cart, n_estimators = 100, random_state=7)

# %%
results = cross_val_score(model, X, Y, cv=kfold)

# %%
results.mean(), results.std()
# Out:
# (0.4903143023083053, 0.02540988443186073)

# %% [markdown]
# **случайный_лес (Random Forest)**

# %%
model = RandomForestClassifier(n_estimators = 100, max_features = 3)

# %%
results = cross_val_score(model, X, Y, cv=kfold)

# %%
results.mean(), results.std()
# Out:
# (0.49392083237660456, 0.01948562805393034)

# %% [markdown]
# **дополнительные_деревья (Extra Trees)**

# %%
model = ExtraTreesClassifier(n_estimators = 100, max_features = 7)

# %%
results = cross_val_score(model, X, Y, cv=kfold)

# %%
results.mean(), results.std()
# Out:
# (0.4720117418768094, 0.01788987403969764)

# %%
lst_1 = list(range(6,10))
lst_2 = list(range(3,4))
lst_3 = list(range(100,200))
k = []

# %%
for s in lst_3:
 model = GradientBoostingClassifier(n_estimators = s, random_state = 7)
 for i in lst_2:
   kfold=KFold(n_splits=i,random_state=7,shuffle=True)
   for j in lst_1:
      test=SelectKBest(score_func=f_classif, k=j)
      fit=test.fit(X,Y)
      features=fit.transform(X)
      results=cross_val_score(model, features, Y, cv=kfold)
      res = results.mean()
      k.append(res)
      print(f'n_splits: {i} KBest: {j} {res}')
   print(f'n_estimators = {s} n_splits = {i} max = {max(k)}')
# Out:
# n_splits: 3 KBest: 6 0.5344321239868246
# n_splits: 3 KBest: 7 0.5353330245226233
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\D9F8~1\AppData\Local\Temp/ipykernel_17880/3359340500.py in <module>
#       7       fit=test.fit(X,Y)
#       8       features=fit.transform(X)
# ----> 9       results=cross_val_score(model, features, Y, cv=kfold)
#      10       res = results.mean()
#      11       k.append(res)
#
# D:\Programs\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\Programs\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     443     scorer = check_scoring(estimator, scoring=scoring)
#     444
# --> 445     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     446                                 scoring={'score': scorer}, cv=cv,
#     447                                 n_jobs=n_jobs, verbose=verbose,
#
# D:\Programs\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\Programs\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     248     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     249                         pre_dispatch=pre_dispatch)
# --> 250     results = parallel(
#     251         delayed(_fit_and_score)(
#     252             clone(estimator), X, y, scorers, train, test, verbose, None,
#
# D:\Programs\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# D:\Programs\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# D:\Programs\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# D:\Programs\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# D:\Programs\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# D:\Programs\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# D:\Programs\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# D:\Programs\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# D:\Programs\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     596             estimator.fit(X_train, **fit_params)
#     597         else:
# --> 598             estimator.fit(X_train, y_train, **fit_params)
#     599
#     600     except Exception as e:
#
# D:\Programs\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     502
#     503         # fit the boosting stages
# --> 504         n_stages = self._fit_stages(
#     505             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
#     506             sample_weight_val, begin_at_stage, monitor)
#
# D:\Programs\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     559
#     560             # fit next stage of trees
# --> 561             raw_predictions = self._fit_stage(
#     562                 i, X, y, raw_predictions, sample_weight, sample_mask,
#     563                 random_state, X_csc, X_csr)
#
# D:\Programs\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     189                 y = np.array(original_y == k, dtype=np.float64)
#     190
# --> 191             residual = loss.negative_gradient(y, raw_predictions_copy, k=k,
#     192                                               sample_weight=sample_weight)
#     193
#
# D:\Programs\lib\site-packages\sklearn\ensemble\_gb_losses.py in negative_gradient(self, y, raw_predictions, k, **kwargs)
#     718         """
#     719         return y - np.nan_to_num(np.exp(raw_predictions[:, k] -
# --> 720                                         logsumexp(raw_predictions, axis=1)))
#     721
#     722     def _update_terminal_region(self, tree, terminal_regions, leaf, X, y,
#
# D:\Programs\lib\site-packages\scipy\special\_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#      97             a[b == 0] = -np.inf
#      98
# ---> 99     a_max = np.amax(a, axis=axis, keepdims=True)
#     100
#     101     if a_max.ndim > 0:
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# D:\Programs\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#
# D:\Programs\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
x_new = XX[1000:1020]
lst_1 = list(range(1,20))
lst_3 = list(range(50,200))
for i in lst_3:
 for j in lst_1:
  model=XGBClassifier(seed = 7, n_estimators = i, max_depth = j, learning_rate = 1,eval_metric='mlogloss')
  model.fit(X,Y)
  for k in x_new:
      predictions = model.predict(XX)
      print (f'n_estimators = {i} max_depth = {k}')
      print(confusion_matrix(YY, predictions))
# Out:
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[ 777  241  337  261]
#  [ 397  410  601  164]
#  [ 178  207 1133  202]
#  [ 355   97   74 1231]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[ 877  267  203  269]
#  [ 368  586  446  172]
#  [ 153  273 1088  206]
#  [ 310   95   49 1303]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[ 932  268  170  246]
#  [ 300  721  377  174]
#  [ 145  257 1130  188]
#  [ 268   83   44 1362]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1067  209  154  186]
#  [ 242  855  332  143]
#  [ 125  218 1231  146]
#  [ 203   56   41 1457]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1174  171  141  130]
#  [ 166 1034  279   93]
#  [  93  168 1344  115]
#  [ 145   50   36 1526]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1334  124   99   59]
#  [ 113 1171  226   62]
#  [  64  119 1471   66]
#  [  76   33   27 1621]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1436   91   60   29]
#  [  67 1305  166   34]
#  [  30   88 1564   38]
#  [  33   15   20 1689]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1512   50   41   13]
#  [  54 1382  119   17]
#  [  20   57 1615   28]
#  [  18   11   12 1716]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1520   51   32   13]
#  [  29 1447   85   11]
#  [  10   48 1640   22]
#  [  11    7   16 1723]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1534   44   27   11]
#  [  37 1455   69   11]
#  [  14   50 1635   21]
#  [  12    7   15 1723]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1534   46   26   10]
#  [  33 1457   74    8]
#  [  14   43 1644   19]
#  [  13    7   17 1720]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# n_estimators = 50 max_depth = [ 0.  1. 38.  0.  3.  4.  3.  1.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  1. 48.  1.  1.  0.  2.  2.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  1. 51.  1.  1.  3.  3.  4.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  1. 73.  1.  1.  1.  1.  2.  2.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  2.  1.  3.  4.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  1. 65.  1.  6.  1.  2.  2.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  0. 36.  0.  1.  0.  3.  1.  5.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  2.  0.  3.  3.  5.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  1. 43.  1.  7.  0.  1.  4.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  1. 33.  1.  9.  0.  1.  2.  3.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  0. 30.  1.  3. 14.  3.  1.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  0. 25.  1.  4.  8.  3.  2.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  1. 49.  1.  1.  4.  2.  4.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  0. 31.  1.  1.  9.  3.  1.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  0. 27.  1.  5. 14.  3.  8.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  0. 33.  1.  3. 11.  3.  3.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  1. 35.  1.  1.  1.  2.  2.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  0. 19.  0.  2.  1.  3.  5.  3.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 0.  1. 25.  0.  8.  0.  1.  5.  4.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# n_estimators = 50 max_depth = [ 1.  1. 57.  0.  7.  4.  1.  4.  6.]
# [[1526   52   26   12]
#  [  26 1466   69   11]
#  [  12   48 1637   23]
#  [  11    7   12 1727]]
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\D9F8~1\AppData\Local\Temp/ipykernel_10300/1393392749.py in <module>
#       7  for j in lst_1:
#       8   model=XGBClassifier(seed = 7, n_estimators = i, max_depth = j, learning_rate = 1,eval_metric='mlogloss')
# ----> 9   model.fit(X,Y)
#      10   for k in x_new:
#      11       predictions = model.predict(XX)
#
# D:\Programs\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# D:\Programs\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1248         )
#    1249
# -> 1250         self._Booster = train(
#    1251             params,
#    1252             train_dmatrix,
#
# D:\Programs\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# D:\Programs\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# D:\Programs\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
YY[1000:1020]
# Out:
# array([2., 3., 2., 3., 3., 2., 2., 2., 2., 3., 4., 1., 3., 2., 3., 1., 1.,
#        4., 4., 3.])

# %%
x_new = XX[1000:1020]
lst_1 = list(range(1,20))
lst_3 = list(range(50,200))

#k = []
for i in lst_3:
 for j in lst_1:
  model=XGBClassifier(seed = 7, n_estimators = i, max_depth = j, learning_rate = 1,eval_metric='mlogloss')
  model.fit(X,Y)
  res = model.predict(x_new)
  print(f'n_estimators:{i} глубина: {j} предсказание: {res}')
#  k.append(res)
# Out:
# n_estimators:50 глубина: 1 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 4. 1. 3. 1. 4. 4. 3. 4. 4. 2.]
# n_estimators:50 глубина: 2 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 1. 4. 3. 1. 4. 4. 3. 4. 1. 2.]
# n_estimators:50 глубина: 3 предсказание: [1. 3. 3. 3. 4. 3. 2. 4. 2. 1. 4. 4. 3. 1. 3. 4. 3. 4. 4. 3.]
# n_estimators:50 глубина: 4 предсказание: [1. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:50 глубина: 5 предсказание: [2. 3. 3. 3. 4. 3. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:50 глубина: 6 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 7 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 3. 4. 4. 3.]
# n_estimators:50 глубина: 8 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 9 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 10 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 11 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 12 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 13 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 14 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 15 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 16 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 17 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 18 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:50 глубина: 19 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 1 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 4. 1. 3. 1. 4. 4. 3. 4. 4. 2.]
# n_estimators:51 глубина: 2 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 1. 4. 3. 1. 4. 4. 3. 4. 1. 2.]
# n_estimators:51 глубина: 3 предсказание: [1. 3. 3. 3. 4. 3. 2. 4. 2. 1. 4. 4. 3. 1. 3. 4. 3. 4. 4. 3.]
# n_estimators:51 глубина: 4 предсказание: [1. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:51 глубина: 5 предсказание: [2. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:51 глубина: 6 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 3. 4. 4. 3.]
# n_estimators:51 глубина: 7 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 3. 4. 4. 3.]
# n_estimators:51 глубина: 8 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 9 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 10 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 11 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 12 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 13 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 14 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 15 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 16 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 17 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 18 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:51 глубина: 19 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 1 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 4. 1. 3. 1. 4. 4. 3. 4. 4. 2.]
# n_estimators:52 глубина: 2 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 1. 4. 3. 1. 4. 4. 3. 4. 1. 2.]
# n_estimators:52 глубина: 3 предсказание: [1. 3. 3. 3. 4. 3. 2. 4. 2. 1. 4. 4. 3. 1. 3. 4. 3. 4. 4. 3.]
# n_estimators:52 глубина: 4 предсказание: [1. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:52 глубина: 5 предсказание: [2. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:52 глубина: 6 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 2. 3. 1. 3. 4. 4. 3.]
# n_estimators:52 глубина: 7 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 3. 4. 4. 3.]
# n_estimators:52 глубина: 8 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 9 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 10 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 11 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 12 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 13 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 14 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 15 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 16 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 17 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 18 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:52 глубина: 19 предсказание: [2. 3. 2. 3. 4. 2. 2. 2. 2. 3. 4. 1. 3. 2. 3. 1. 2. 4. 4. 3.]
# n_estimators:53 глубина: 1 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 4. 1. 3. 1. 4. 4. 3. 4. 4. 2.]
# n_estimators:53 глубина: 2 предсказание: [1. 3. 3. 3. 4. 3. 1. 4. 2. 1. 1. 4. 3. 1. 4. 4. 3. 4. 1. 2.]
# n_estimators:53 глубина: 3 предсказание: [1. 3. 3. 3. 4. 3. 2. 4. 2. 1. 4. 4. 3. 1. 3. 4. 3. 4. 4. 3.]
# n_estimators:53 глубина: 4 предсказание: [1. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# n_estimators:53 глубина: 5 предсказание: [2. 3. 3. 3. 4. 2. 2. 2. 2. 3. 4. 4. 3. 1. 3. 1. 3. 4. 4. 3.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\D9F8~1\AppData\Local\Temp/ipykernel_10300/2054713206.py in <module>
#       7  for j in lst_1:
#       8   model=XGBClassifier(seed = 7, n_estimators = i, max_depth = j, learning_rate = 1,eval_metric='mlogloss')
# ----> 9   model.fit(X,Y)
#      10   res = model.predict(x_new)
#      11   print(f'n_estimators:{i} глубина: {j} предсказание: {res}')
#
# D:\Programs\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# D:\Programs\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1248         )
#    1249
# -> 1250         self._Booster = train(
#    1251             params,
#    1252             train_dmatrix,
#
# D:\Programs\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# D:\Programs\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# D:\Programs\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
kfold=KFold(n_splits=3,random_state=7,shuffle=True)

model=XGBClassifier(seed = 7, n_estimators = 50, max_depth = 12, learning_rate = 0.3,eval_metric='mlogloss')

results=cross_val_score(model, X, Y, cv=kfold)

model.fit(X,Y)

results.mean(),results.std()
# Out:
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# D:\Programs\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\D9F8~1\AppData\Local\Temp/ipykernel_10300/3403117368.py in <module>
#       5 results=cross_val_score(model, X, Y, cv=kfold)
#       6
# ----> 7 model.fit(X,Y)
#       8
#       9 results.mean(),results.std()
#
# D:\Programs\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# D:\Programs\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1248         )
#    1249
# -> 1250         self._Booster = train(
#    1251             params,
#    1252             train_dmatrix,
#
# D:\Programs\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# D:\Programs\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# D:\Programs\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:
